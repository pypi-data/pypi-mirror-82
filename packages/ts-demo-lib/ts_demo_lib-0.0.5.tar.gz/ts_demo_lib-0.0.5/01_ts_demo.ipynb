# %%
# default_exp ts_demo

# %%
#export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
#export
def say_hello1(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
#export
def say_hello2(to):
    "Say hello to somebody"
    return f'Hello2 {to}!'

# %% [markdown]
# ## Tests

# %%
from fastcore.test import *

# %%
test_eq(say_hello("tscience"), "Hello tscience!")

# %%
test_eq(say_hello1("tscience"), "Hello tscience!")

# %%
test_eq(say_hello2("tscience"), "Hello2 tscience!")

# %% [markdown]
# ## Exports

# %%
from nbdev.export import *
notebook2script()
# Out:
# Converted 01_ts_demo.ipynb.
# Converted index.ipynb.
